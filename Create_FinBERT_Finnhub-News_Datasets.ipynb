# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification # type: ignore

tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

# %%
from datasets import load_dataset # type: ignore

ds = load_dataset("sehyun66/Finnhub-News", "clean")

# %%
import pandas as pd # type: ignore

pdds = pd.DataFrame(ds['clean'])
pdds = pdds.drop(columns=['image','source','url','id'])
pdds
# Out:
#              datetime related  \
# 0       1682380800000   GOOGL
# 1       1691366400000    JJSF
# 2       1681776000000    TSLA
# 3       1682553600000    PCAR
# 4       1678752000000    RFIL
# ...               ...     ...
# 316081  1686873600000    TECH
# 316082  1673913600000    FFIV
# 316083  1686182400000    CSIQ
# 316084  1688169600000    BPMC
# 316085  1692835200000    PTON
#
#                                                   summary category  \
# 0       Looking for stock market analysis and research...  company
# 1       The spicy cheddar flavored popcorn is availabl...  company
# 2       Toyota and other Japanese carmakers are suffer...  company
# 3                                                          company
# 4                 Q1 2023 RF Industries Ltd Earnings Call  company
# ...                                                   ...      ...
# 316081  Looking for stock market analysis and research...  company
# 316082  F5 (FFIV) doesn't possess the right combinatio...  company
# 316083  Looking for stock market analysis and research...  company
# 316084  Looking for stock market analysis and research...  company
# 316085  Looking for stock market analysis and research...  company
#
#                                                  headline
# 0          Notable companies reporting after market close
# 1       Get Fired Up with Doc Popcorn's Latest Limited...
# 2       Japanese carmakers’ China sales hit by sluggis...
# 3       BMO Capital Maintains Paccar (PCAR) Market Per...
# 4                 Q1 2023 RF Industries Ltd Earnings Call
# ...                                                   ...
# 316081        Why Nvidia Stock Is Surging Premarket Today
# 316082  Earnings Preview: F5 Networks (FFIV) Q1 Earnin...
# 316083  Canadian Solar's CSI Energy selected to provid...
# 316084  Week In Review: CMBG Out-Licenses Two CAR-T Ca...
# 316085                      Peloton Needs to Fire Its CEO
#
# [316086 rows x 5 columns]

# %%
pdds['datetime'] =pd.to_datetime(pdds['datetime'], unit='ms')
pdds
# Out:
#          datetime related                                            summary  \
# 0      2023-04-25   GOOGL  Looking for stock market analysis and research...
# 1      2023-08-07    JJSF  The spicy cheddar flavored popcorn is availabl...
# 2      2023-04-18    TSLA  Toyota and other Japanese carmakers are suffer...
# 3      2023-04-27    PCAR
# 4      2023-03-14    RFIL            Q1 2023 RF Industries Ltd Earnings Call
# ...           ...     ...                                                ...
# 316081 2023-06-16    TECH  Looking for stock market analysis and research...
# 316082 2023-01-17    FFIV  F5 (FFIV) doesn't possess the right combinatio...
# 316083 2023-06-08    CSIQ  Looking for stock market analysis and research...
# 316084 2023-07-01    BPMC  Looking for stock market analysis and research...
# 316085 2023-08-24    PTON  Looking for stock market analysis and research...
#
#        category                                           headline
# 0       company     Notable companies reporting after market close
# 1       company  Get Fired Up with Doc Popcorn's Latest Limited...
# 2       company  Japanese carmakers’ China sales hit by sluggis...
# 3       company  BMO Capital Maintains Paccar (PCAR) Market Per...
# 4       company            Q1 2023 RF Industries Ltd Earnings Call
# ...         ...                                                ...
# 316081  company        Why Nvidia Stock Is Surging Premarket Today
# 316082  company  Earnings Preview: F5 Networks (FFIV) Q1 Earnin...
# 316083  company  Canadian Solar's CSI Energy selected to provid...
# 316084  company  Week In Review: CMBG Out-Licenses Two CAR-T Ca...
# 316085  company                      Peloton Needs to Fire Its CEO
#
# [316086 rows x 5 columns]

# %%
aapl = pdds[pdds['related'].str.contains('|'.join(['AAPL', 'GOOGL','AMZN']))]
aapl = aapl.drop(aapl[aapl['summary']==''].index)
aapl = aapl.drop(aapl[aapl['headline']==''].index)
aapl
# Out:
#          datetime related                                            summary  \
# 0      2023-04-25   GOOGL  Looking for stock market analysis and research...
# 52     2023-07-21   GOOGL  Looking for stock market analysis and research...
# 77     2023-02-24    AMZN  Hundreds of e-commerce vendors and platforms i...
# 112    2023-07-28    AMZN  (Bloomberg) -- Indonesia is planning to restri...
# 124    2023-06-30    AAPL  American Express is in talks to take over Gold...
# ...           ...     ...                                                ...
# 315924 2023-05-17    AAPL  Looking for stock market analysis and research...
# 315945 2023-04-08   GOOGL  Google Flights is out with its "top summer des...
# 316028 2023-04-18    AMZN  Looking for stock market analysis and research...
# 316051 2023-08-30   GOOGL  Looking for stock market analysis and research...
# 316052 2023-01-24   GOOGL  The lawsuit seeks to force the Alphabet unit t...
#
#        category                                           headline
# 0       company     Notable companies reporting after market close
# 52      company  YouTube Premium raises prices in the U.S. to $...
# 77      company  Retail giants Walmart, Alibaba and Amazon draw...
# 112     company  Indonesia Plans Imported Goods Restrictions in...
# 124     company  Goldman Is Looking for a Way Out of Its Partne...
# ...         ...                                                ...
# 315924  company  Apple relies on China for components despite I...
# 315945  company  Google Flights Just Released Its Most Popular ...
# 316028  company        Amazon vs Alibaba: Which Is a Better Value?
# 316051  company  Instagram Is Testing TikTok-Style 10-Minute Re...
# 316052  company  U.S. Files New Antitrust Suit Against Google O...
#
# [12355 rows x 5 columns]

# %%
import numpy as np # type: ignore

headlines_array = np.array(aapl)
i=0
rango = 100
inputsArray =[]

while len(headlines_array) > i*rango:
    headlines_list = list(headlines_array[i*rango:(i+1)*rango, 4])
    inputsArray.append(tokenizer(headlines_list, padding = True, truncation = True, return_tensors='pt'))
    i = i + 1

# %%
import torch # type: ignore

positive = []
negative = []
neutral = []

for inputs in inputsArray:
    outputs = model(**inputs)
    predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
    
    positive.extend(predictions[:, 0].tolist())
    negative.extend(predictions[:, 1].tolist())
    neutral.extend(predictions[:, 2].tolist())

# %%
model.config.id2label

table = {'Date':headlines_array[:,0],
         'Stock': headlines_array[:,1],
         'Headline':headlines_array[:,4],
         "Positive":positive,
         "Negative":negative, 
         "Neutral":neutral}
      
df = pd.DataFrame(table, columns = ["Date","Stock", "Headline", "Positive", "Negative", "Neutral"])
df = df.sort_values("Date")
df = df.reset_index(drop=True)
df.to_csv('Datasets/Finnhub-News-2023_Sentiment.csv', index=False)
df
# Out:
#             Date  Stock                                           Headline  \
# 0     2020-08-05   AMZN                        10 Biggest Retail Companies
# 1     2021-04-28   AAPL        Inside Intel: A Look at the Mega Chip Maker
# 2     2021-07-28   AAPL    Why Not Every Break Of Support Is A Sell Signal
# 3     2022-07-20   AAPL  Stock Market Today: Track Market Trends And Th...
# 4     2022-12-01   AAPL  Best Dow Jones Stocks To Buy And Watch In Dece...
# ...          ...    ...                                                ...
# 12350 2023-08-30  GOOGL  Google AI will be able to go to meetings for y...
# 12351 2023-08-30  GOOGL  Google Announces Oct. 4 Event: Pixel 8 Series,...
# 12352 2023-08-30  GOOGL  Did Google Just Accidentally Leak Official Ima...
# 12353 2023-08-30   AAPL  Russia earns less from oil and spends more on ...
# 12354 2023-08-30   AAPL  India says Dell, HP and others want to manufac...
#
#        Positive  Negative   Neutral
# 0      0.054260  0.026028  0.919712
# 1      0.066666  0.014147  0.919186
# 2      0.040128  0.099163  0.860709
# 3      0.042219  0.031128  0.926652
# 4      0.061930  0.027586  0.910484
# ...         ...       ...       ...
# 12350  0.100624  0.010109  0.889267
# 12351  0.034578  0.017830  0.947591
# 12352  0.018241  0.731800  0.249959
# 12353  0.083143  0.308467  0.608390
# 12354  0.131391  0.011186  0.857424
#
# [12355 rows x 6 columns]
